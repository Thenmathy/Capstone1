# %%
#!pip insatll pandas has been done in the terminal

# %%
import pandas as pd

# %%
#Reading the data
df2 = pd.read_csv(r'C:\Users\DELL\Desktop\Capstone-1\traffic_stops - traffic_stops_with_vehicle_number (1).csv')
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_10412\960904243.py:2: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   df2 = pd.read_csv(r'C:\Users\DELL\Desktop\Capstone-1\traffic_stops - traffic_stops_with_vehicle_number (1).csv')

# %%
#displaying the first few rows
df2.head(5)
# Out:
#     stop_date stop_time country_name driver_gender  driver_age_raw  \
# 0  2020-01-01   0:00:00       Canada             M              59
# 1  2020-01-01   0:01:00        India             M              35
# 2  2020-01-01   0:02:00          USA             M              26
# 3  2020-01-01   0:03:00       Canada             M              26
# 4  2020-01-01   0:04:00       Canada             M              62
#
#    driver_age driver_race     violation_raw violation  search_conducted  \
# 0          19       Asian     Drunk Driving  Speeding              True
# 1          58       Other             Other     Other             False
# 2          76       Black  Signal Violation  Speeding             False
# 3          76       Black          Speeding       DUI              True
# 4          75       Other          Speeding     Other             False
#
#       search_type stop_outcome  is_arrested stop_duration  drugs_related_stop  \
# ...

# %%
df2['search_type'].isna().sum()
# Out:
# np.int64(21720)

# %%
df2['search_type'] = df2['search_type'].fillna('empty')

# %%
df2['search_type'].isna().sum()
# Out:
# np.int64(0)

# %%
df2['stop_date']=pd.to_datetime(df2['stop_date'],format='%Y-%m-%d')
display(df2)
# Out:
#        stop_date stop_time country_name driver_gender  driver_age_raw  \
# 0     2020-01-01   0:00:00       Canada             M              59
# 1     2020-01-01   0:01:00        India             M              35
# 2     2020-01-01   0:02:00          USA             M              26
# 3     2020-01-01   0:03:00       Canada             M              26
# 4     2020-01-01   0:04:00       Canada             M              62
# ...          ...       ...          ...           ...             ...
# 65533 2020-02-15  12:13:00        India             F              54
# 65534 2020-02-15  12:14:00       Canada             F              18
# 65535 2020-02-15  12:15:00          USA             M              27
# 65536 2020-02-15  12:16:00       Canada             F              49
# 65537 2020-02-15  12:17:00          USA             F              72
#
#        driver_age driver_race     violation_raw violation  search_conducted  \
# ...

# %%
df2['stop_time']=pd.to_datetime(df2['stop_time'],format='%H:%M:%S')
print(df2)
# Out:
#        stop_date           stop_time country_name driver_gender  \
# 0     2020-01-01 1900-01-01 00:00:00       Canada             M
# 1     2020-01-01 1900-01-01 00:01:00        India             M
# 2     2020-01-01 1900-01-01 00:02:00          USA             M
# 3     2020-01-01 1900-01-01 00:03:00       Canada             M
# 4     2020-01-01 1900-01-01 00:04:00       Canada             M
# ...          ...                 ...          ...           ...
# 65533 2020-02-15 1900-01-01 12:13:00        India             F
# 65534 2020-02-15 1900-01-01 12:14:00       Canada             F
# 65535 2020-02-15 1900-01-01 12:15:00          USA             M
# 65536 2020-02-15 1900-01-01 12:16:00       Canada             F
# 65537 2020-02-15 1900-01-01 12:17:00          USA             F
#
#        driver_age_raw  driver_age driver_race     violation_raw violation  \
# 0                  59          19       Asian     Drunk Driving  Speeding
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65538 entries, 0 to 65537
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   stop_date           65538 non-null  datetime64[ns]
#  1   stop_time           65538 non-null  datetime64[ns]
#  2   country_name        65538 non-null  object
#  3   driver_gender       65538 non-null  object
#  4   driver_age_raw      65538 non-null  int64
#  5   driver_age          65538 non-null  int64
#  6   driver_race         65538 non-null  object
#  7   violation_raw       65538 non-null  object
#  8   violation           65538 non-null  object
#  9   search_conducted    65538 non-null  bool
#  10  search_type         65538 non-null  object
#  11  stop_outcome        65538 non-null  object
#  12  is_arrested         65538 non-null  bool
#  13  stop_duration       65538 non-null  object
#  14  drugs_related_stop  65538 non-null  bool
# ...

# %%
df2.to_csv("Cleanedsecurelog.csv")

# %%
#SQL connection#!pip install mysql-connector-python done in the terminal

# %%
import mysql.connector

# %%
Securelogs = mysql.connector.connect(
    host="localhost",
    user="root",
    password="09876",
    database="Securelogs",
    autocommit=True
)
mycursor = Securelogs.cursor()

# %%
mycursor.execute("create database Securelogs")
# Out:
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# File c:\Users\DELL\Desktop\Capstone-1\.venv\Lib\site-packages\mysql\connector\connection_cext.py:772, in CMySQLConnection.cmd_query(self, query, raw, buffered, raw_as_string, **kwargs)
#     770     self._local_infile_filenames = None
# --> 772     self._cmysql.query(
#     773         query,
#     774         raw=raw,
#     775         buffered=buffered,
#     776         raw_as_string=raw_as_string,
#     777         query_attrs=self.query_attrs,
#     778     )
#     779 except MySQLInterfaceError as err:
#
# MySQLInterfaceError: Can't create database 'securelogs'; database exists
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 mycursor.execute("create database Securelogs")
#
# ...

# %%
mycursor.execute("""
    CREATE TABLE Securelogs.policetraff (
        stop_date DATETIME,
        stop_time DATETIME,
        country_name VARCHAR(60),
        driver_gender VARCHAR(60),
        driver_age_raw INT,
        driver_age INT,
        driver_race VARCHAR(70),
        violation_raw VARCHAR(40),
        violation VARCHAR(60),
        search_conducted VARCHAR(60),
        search_type VARCHAR(60),
        stop_outcome VARCHAR(60),
        is_arrested VARCHAR(60),
        stop_duration VARCHAR(60),
        drugs_related_stop VARCHAR(60),
        vehicle_number VARCHAR(60)
    )
""")

# %%
#Step 10: Inserting Data into the Table
#pip install mysql-connector-python sqlalchemy done in terminal
from sqlalchemy import create_engine

engine = create_engine("mysql+mysqlconnector://root:09876@localhost/Securelogs")

# %%
print(type(engine))
# Out:
# <class 'sqlalchemy.engine.base.Engine'>

# %%
df2.to_sql(name='Ledger', con=engine, if_exists='append', index=False)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_22076\2251232983.py:1: UserWarning: The provided table name 'Ledger' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df2.to_sql(name='Ledger', con=engine, if_exists='append', index=False)
# 65538

# %%
Securelogs
